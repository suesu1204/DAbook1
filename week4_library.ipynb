# %% [markdown]
# **실습 문제**

# %% [markdown]
# 1.3) 파이썬으로 하는 데이터 시각화

# %%
import matplotlib.pyplot as plt
xdata=[2,3,4,5]
ydata=[1,3,5,7]
plt.plot(xdata,ydata)
plt.show()

# %% [markdown]
# 2.1) 시각화 옵션

# %%
import matplotlib.pyplot as plt
plt.title('Line Graph')#그래프 제목 지정
xdata=[2,3,4,5]
ydata=[1,3,5,7]
plt.plot(xdata,ydata)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.title('Legend')
data1=[1,5,7,9]
data2=[9,5,3,2]
plt.plot(data1,label='data1',linestyle='--',color='green')#두개의 데이터 한 그래프로 나타내기, 이름 지정
plt.plot(data2,label='data2',linestyle='-.',color='blue')#실선은 -.점선은 :, 파선은 --, 점쇄선은 -.이다.
plt.xlabel('index')
plt.ylabel('value')
plt.legend()#반드시 호출해주어야 한다.
plt.show()

# %%
import matplotlib.pyplot as plt
xdata=[2,3,4,5]
ydata=[3,4,5,6]
plt.plot(xdata,ydata,color='orange',linestyle=':')#색상 지정
plt.show()

# %%
import matplotlib.pyplot as plt
xdata=[2,3,4,5]
ydata=[3,4,5,6]
plt.xlabel('xdata')#x축 y축 이름 지정
plt.ylabel('ydata')#데이터 plot에 넣는과 라벨 지정하는 순서 뒤집어도 상관이 없다.
plt.plot(xdata,ydata)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.title('x, y range')
xdata=[2,3,4,5]
ydata=[5,10,24 ,60]
plt.plot(xdata,ydata,linestyle='--',marker='o',markersize='7')#마커 속성과 색상 속성 확인
plt.xlim(1,7)#보여지는 범위를 조정할 수 있다.
plt.ylim(0,100)
plt.show()

# %%
#판다스를 이용하면 시각화 라이브러리 없이도 내장 라이브러리를 이용하여 기본적인 시각화를 할 수 있다.
#plot 함수의 kind 속성을 지정하면 다양한 종류의 그래프 활용 가능하다.(line, bar, barh,hist,box)

# %%
import pandas as pd
score=[[100,20,30],[20,30,40],[40,60,50],[10,30,100]]
subject=['math','eng','korean']
df=pd.DataFrame(score, columns=subject)
print(df.plot(kind='bar'))
print(df.plot(kind='line'))
print(df.plot(kind='area'))
print(df.plot(kind='box'))
# Out:
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)

# %% [markdown]
# 2.2) 선 그래프<br>
# 선 그래프는 연속적으로 변하는 데이터를 시각화 할 때 적당하다<br>특히 시간 변화량을 나타내는 시계열 데이터를 표현하는 그래프에도 많이 사용한다.

# %%
import pandas as pd
import matplotlib.pyplot as plt

data=pd.read_excel('./sample_data/fine_dust.xlsx',index_col='area')
data2018=data[2018]
data2018
# Out:
# area
# Seoul          40.0
# Gyeonggi       44.0
# Incheon        40.0
# Busan          41.0
# Daegu          39.0
# Gwangju        41.0
# Daejeon        44.0
# Ulsan          40.0
# Sejong         40.0
# Gangwon        38.0
# Chungcheong    41.5
# Jeolla         39.0
# Gyeongsang     42.5
# Jeju           35.0
# Name: 2018, dtype: float64

# %%
plt.figure(figsize=(15,4)) #그래프 사이즈 조정
plt.plot(data2018, color='r',marker='o')#선그래프, x,y를 지정하지 않아도 된다.
plt.xlabel('area')
plt.ylabel('micrometer')
plt.title('fine dust')
plt.grid()#격자표시 활성화
plt.show()#보여주기

# %%
plt.figure(figsize=(15,4))
for year in range(2016,2020):
  chartdata=data[year]
  plt.plot(chartdata,label=year)

plt.xlabel('area')
plt.ylabel('micrometer')
plt.title('fine dust')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# 2.3) 막대 그래프<br>
# - 집단 별 차이를 표현할때는 막대그래프가 적당하다(크고 작음의 차이를 한눈에 파악할 때-수량의 많고 적음, 변화된 양에 대한 일월연별 통계등의 비교)
# - 가독성 면에서 항목의 개수가 적으면 가로막대,  많으면 세로막대가 좋다.

# %%
import pandas as pd
import matplotlib.pyplot as plt

data=pd.read_excel('./sample_data/fine_dust.xlsx',index_col='area')
data2017=data[2017]
print(data2017)
plt.figure(figsize=(15,4))#size 지정은 plt에 값을 담기전에 해야한다.
plt.bar(data2017.index,data2017, color='g')#bar 그래프는 x축, y축을 지정해주어야 한다.
plt.xlabel('area')
plt.ylabel('micrometer')
plt.title('2017 Fine Dust Bar Graph')
plt.grid()
plt.ylim(0,70)
plt.show()
# Out:
# area
# Seoul          44.0
# Gyeonggi       51.0
# Incheon        46.0
# Busan          44.0
# Daegu          42.0
# Gwangju        40.0
# Daejeon        45.0
# Ulsan          43.0
# Sejong         47.0
# Gangwon        44.0
# Chungcheong    44.0
# Jeolla         42.0
# Gyeongsang     41.5
# Jeju           37.0
# Name: 2017, dtype: float64

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data=pd.read_excel('./sample_data/fine_dust.xlsx',index_col='area')
index=np.arange(4)#[0,1,2,3]반환한다
plt.figure(figsize=(15, 4))
data4=data.loc['Gyeonggi':'Daegu',2016:2019]
data4
for year in range(2016,2020):
  chartdata=data4[year]
  plt.bar(index,chartdata,width=0.2,label=year)
  index=index+0.2#[0.2,1.2,2.2,3.2]이런식으로 쭉쭉 나간다.

plt.ylim(35,55)
plt.xlabel('area')
plt.ylabel('micrometer')
plt.xticks(index-0.5, ['Gyeonggi','Incheon','Busan','Daegu'])
plt.title('fine dust')
plt.legend()
plt.grid()
plt.show()

# %%
index=np.arange(4)#[0,1,2,3]반환한다
plt.figure(figsize=(10, 4))
data4=data.loc['Gyeonggi':'Daegu',2016:2019]

for year in range(2016,2020):
  chartdata=data4[year]
  plt.barh(index,chartdata,label=year)

plt.xlim(30,55)
plt.ylabel('area')
plt.xlabel('micrometer')
plt.yticks(index, ['Gyeonggi','Incheon','Busan','Daegu'])#여기서는 그래프를 안덱스 기준으로 따로 나누지 않아도 된다.
plt.title('fine dust')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# 2.4) 산점도 그래프
# - 서로 다른 두 연속형 변수 사이의 관계를 나타내고 연속형 변수의 상관성을 확인할 때 산점도 그래프를 사용
# - ex) 나이와 소득에 대한 상호 관련성 파악

# %%
import matplotlib.pyplot as plt
import pandas as pd

data=pd.read_excel('health_screenings_2020_1000ea.xlsx')
heightdata=data['height']
weightdata=data['weight']

plt.figure(figsize=(10,4))
plt.scatter(heightdata,weightdata)
plt.title('Scatter Graph')
plt.xlabel('height')
plt.ylabel('weight')
plt.grid()
plt.show()

# %%
#그룹 산점도 그래프 그리기(기존 산점도 위에 산점도 그래프를 하나 더 그림)
systolicdata=data['systolic']
diastolicdata=data['diastolic']
blood_sugardata=data['blood_sugar']

plt.figure(figsize=(10,6))

plt.scatter(systolicdata,diastolicdata,label='systolic*distolic', color='r', edgecolors='w')
plt.scatter(diastolicdata, blood_sugardata,label='blood_sugar*distolic',color='g',edgecolors='w')
plt.scatter(systolicdata,blood_sugardata,label='systolic*blood_sugar',edgecolors='w',color='b')

plt.title('Scatter Graph')
plt.xlim(40, 180)
plt.ylim(30,300)
plt.legend()#범례지정
plt.grid()
plt.show()

# %% [markdown]
# 2.5) 히스토그램 그래프
# - 변수가 하나인 데이터의 빈도수를 막대 모양으로 나타낼 때 적당
# - 데이터의 분석 및 분포를 파악하는 역할을 한다.

# %%
import matplotlib.pyplot as plt
import pandas as pd

data=pd.read_excel('health_screenings_2020_1000ea.xlsx')

female_data=data.loc[data.gender==2,['gender','height']]#두가지 변수를 여성인것만 가져온다.
plt.hist(female_data['height'],bins=7,label='Female')#계급개수 7개

plt.xlabel('height')
plt.ylabel('frequency')
plt.title('histogram graph')
plt.xlim(130,180)
plt.legend()
plt.grid()
plt.show()

# %%
#그룹히스토그램 그리기
female_data=data.loc[data.gender==2,['gender','height']]#두가지 변수를 여성인것만 가져온다.
male_data=data.loc[data.gender==1,['gender','height']]
plt.hist(female_data['height'],bins=7,label='Female')#계급개수 7개
plt.hist(male_data['height'],bins=7,label='Male',color='r')

plt.xlabel('height')
plt.ylabel('frequency')
plt.title('histogram graph')
plt.xlim(130,195)
plt.legend()
plt.grid()
plt.show()

# %%
#누적 히스토그램그래프
import numpy as np
height=np.array([male_data['height'],female_data['height']],dtype=object)# 객체배열로 저장

plt.figure(figsize=(10,6))
plt.hist(height,bins=6,label=['Male','Female'],stacked=True)#값을 합친다

plt.xlim(130,195)
plt.title('histogram graph')
plt.xlabel('height')
plt.ylabel('frequency')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# 2.6) 상자수염 그래프
# - 극단치를 확인하는 그래프

# %%
import numpy as np
height=np.array([male_data['height'],female_data['height']],dtype=object)

plt.figure(figsize=(8,5))
plt.boxplot(height,labels=['Male','Female'])#상자수염 그래프

plt.ylim(130,200)
plt.xlabel('gender')
plt.ylabel('height')
plt.title('boxplot graph')
plt.grid()
plt.show()

# %%
#가로 상자수염 그래프
plt.figure(figsize=(8,5))
plt.boxplot(height,labels=['Male','Female'],vert=False)#상자수염 그래프

plt.xlim(130,200)
plt.ylabel('gender')
plt.xlabel('height')
plt.title('boxplot graph')
plt.grid()
plt.show()

# %% [markdown]
# **seaborn 라이브러리<br>**
# 3.1) 데이터 시각화 준비하기

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt#seaborn을 사용하려면 맷플롯립을 임포트 해야한다.
import seaborn as sns

data=pd.read_excel('health_screenings_2020_1000ea.xlsx')
data.head()
# Out:
#    year  city_code  gender  age_code  height  weight  waist  eye_left  \
# 0  2020         36       1         9     165      60   72.1       1.2
# 1  2020         27       2        13     150      65   81.0       0.8
# 2  2020         11       2        12     155      55   70.0       0.6
# 3  2020         31       1        13     160      70   90.8       1.0
# 4  2020         41       2        12     155      50   75.2       1.5
#
#    eye_right  hear_left  ...  serum   AST   ALT   GTP  smoking  drinking  \
# 0        1.5          1  ...    1.1  21.0  27.0  21.0        1         0
# 1        0.8          1  ...    0.5  18.0  15.0  15.0        1         0
# 2        0.7          1  ...    0.7  27.0  25.0   7.0        1         0
# 3        1.0          1  ...    1.2  65.0  97.0  72.0        1         0
# 4        1.2          1  ...    0.7  18.0  17.0  14.0        1         0
#
#    oral_check  dental_caries  tartar  open_date
# 0           0            NaN     NaN 2021-12-29
# ...

# %%
data6= data.loc[:,['gender','height','weight','waist', 'drinking','smoking']]
data6.loc[data6['gender']==1,['gender']]='Male'
data6.loc[data6['gender']==2,['gender']]='Female'
data6.loc[data6['drinking']==0,['drinking']]='Non-drinking'
data6.loc[data6['drinking']==1,['drinking']]='Drinking'
data6.loc[(data6['smoking']==1)|(data6['smoking']==2),['smoking']]='Non-smoking'
data6.loc[data6['smoking']==3,['smoking']]='Smoking'
data6.head()
# Out:
#    gender  height  weight  waist      drinking      smoking
# 0    Male     165      60   72.1  Non-drinking  Non-smoking
# 1  Female     150      65   81.0  Non-drinking  Non-smoking
# 2  Female     155      55   70.0  Non-drinking  Non-smoking
# 3    Male     160      70   90.8  Non-drinking  Non-smoking
# 4  Female     155      50   75.2  Non-drinking  Non-smoking

# %% [markdown]
# 3.2) 시본 막대 그래프
# - barplot()함수로 속성 3개를 지정하여범주별 그룹을 쉽게 표현 가능
# - 신뢰구간을 표준편차로 하고 싶다면 ci='sd'로 지정한다.

# %%
drinking=data6.groupby(['gender','drinking'])['drinking'].count()
smoking=data6.groupby(['gender','smoking'])['smoking'].count()
drinking=drinking.to_frame(name='count').reset_index()#drinking의 속성값을 count로 지정하고 index초기화
smoking=smoking.to_frame(name='count').reset_index()
print(drinking)
print(smoking)
# Out:
#    gender      drinking  count
# 0  Female      Drinking    213
# 1  Female  Non-drinking    305
# 2    Male      Drinking    356
# 3    Male  Non-drinking    126
#    gender      smoking  count
# 0  Female  Non-smoking    500
# 1  Female      Smoking     18
# 2    Male  Non-smoking    321
# 3    Male      Smoking    161

# %%
#seaborn을 이용하지 않을때
fig=plt.figure(figsize=(17,6))
fig.suptitle('Bar Graph',fontweight='bold') #title지정
index=np.arange(4)

fig.add_subplot(1,2,1)#1행 2열의 subplot 중 첫번째 subplot을 생성한다.

plt.bar(index,drinking['count'])
plt.title('Drinking Type')
plt.ylabel('Count')
plt.xticks(index, ['Non-drinking(Female)','Drinking(Female)','Non-drinking(Male)','Drinking(Male)'])

fig.add_subplot(1,2,2)

plt.bar(index,smoking['count'])
plt.title('Smoking Type')
plt.ylabel('Count')
plt.xticks(index, ['Non-smoking(Female)','Smoking(Female)','Non-smoking(Male)','Smoking(Male)'])

plt.show()

# %%
#seaborn 이용해서 만들때
fig=plt.figure(figsize=(17,6))

area1=fig.add_subplot(1,2,1)
area2=fig.add_subplot(1,2,2)

ax1=sns.barplot(data=drinking,x='gender',y='count',hue='drinking',ax=area1)#hue속성에서는 성별 음주 여부 그룹별 데이터를 지정하여 첫 번째 서브 플롯에 배치한다.
ax2=sns.barplot(data=smoking,x='gender',y= 'count',hue='smoking',ax=area2)

fig.suptitle('Seaborn Bar Graph',fontweight='bold')
area1.set_title('Drinking Type')
area2.set_title('Smoking Type')


plt.show()

# %% [markdown]
# 3.3) 시본 산점도 그래프
# - strip plot 그래프, swarm plot그래프 등이 있다.
# - 맷플롯립의 산점도보다 범주에 따른 각 분포의 실제 데이터나 전체 형상 등을 보여준다.

# %%
male_data=data6.loc[data6.gender=='Male',['gender','weight','waist','drinking','smoking']]
female_data=data6.loc[data6.gender=='Female',['gender','weight','waist','drinking','smoking']]
print(max(male_data['waist']))
print(max(female_data['waist']))
print(male_data)
# Out:
# 128.0
# 109.0
#     gender  weight  waist      drinking      smoking
# 0     Male      60   72.1  Non-drinking  Non-smoking
# 3     Male      70   90.8  Non-drinking  Non-smoking
# 5     Male      85   94.0      Drinking      Smoking
# 6     Male      80   93.0      Drinking      Smoking
# 7     Male      65   92.0  Non-drinking      Smoking
# ..     ...     ...    ...           ...          ...
# 991   Male      60   87.0      Drinking      Smoking
# 994   Male      65   82.0      Drinking  Non-smoking
# 995   Male      70   92.0      Drinking      Smoking
# 996   Male      70   88.0  Non-drinking  Non-smoking
# 999   Male      60   86.0      Drinking  Non-smoking
#
# [482 rows x 5 columns]

# %%
#시본 스트립플롯 그래프(데이터 분포를 요약하여 간단히 띠 형태로 보여주는 그래프, 작은 데이터를 다루는 용도로 사용되고, 큰 데이터를 다룰 때는 주로 히스토그램 등을 많이 사용한다.)
#질문
plt.figure(figsize=(10,5))
plt.title('Seaborn Strip Plot Graph')

sns.stripplot(data=male_data,x='waist',y='weight')
sns.stripplot(data=female_data,x='waist',y='weight')

plt.xticks(np.arange(0,127,63),labels=[53,90.5,128])
plt.show()

# %%
#질문- 128위로 나타나는 값은 뭘까?
plt.figure(figsize=(10,5))
plt.title('Seaborn Swarm Plot Graph-color')

sns.stripplot(data=male_data,x='waist',y='weight',hue='gender',palette='dark')
sns.stripplot(data=female_data,x='waist',y='weight',hue='gender',palette='Set1')

plt.xticks(np.arange(0,127,63),labels=[53,90.5,128])
plt.show()

# %%
#시본 스웜 플롯 그래프 그리기
#점들이 보정되서 서로 겹쳐지지 않는다.- 분포를 표현할때는 좋지만 큰 수 관찰 값의 양을 어림잡을 때는 좋지 않다.

# %%
male_data_100=male_data.head(100)
female_data_100=female_data.head(100)
plt.figure(figsize=(10,5))
plt.title('Seaborn Swarm Plot Graph')

sns.swarmplot(data=male_data_100,x='waist',y='weight',hue='gender',palette='dark',size=4)
sns.swarmplot(data=female_data_100,x='waist',y='weight',hue='gender',palette='Set1',size=4)

plt.xticks(np.arange(0,46,22.5),labels=[53,75.5,98])
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 25.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 40.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# 3.4) 시본 히스토그램 그래프
# - histplot()은 hist()함수와 달리 데이터 분포와 밀도를 확인 할 수 있어 많이 사용한다.

# %%
plt.figure(figsize=(10,6))
sns.histplot(male_data['weight'],bins=7,label='Male',alpha=0.5,kde=True)#kde(커널 밀도 추정 속성)을 추가하면 부드러문 형태의 분포 곡선을 추가로 보여준다.
sns.histplot(female_data['weight'],bins=7,label='Female',alpha=0.5,color='r',kde=True)#투명도가 0.5

plt.xlim(20,130)
plt.xlabel('weight')
plt.ylabel('count')
plt.title('histogram seaborn+kde')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# 3.5) 시본 상자수염 그래프
# - hue 속성으로 매우 쉽게 상자수염 그래프를 그릴 수 있다.

# %%
plt.figure(figsize=(10,6))
plt.title('Seaborn Box Plot Graph')

# sns.boxplot(data=data6,x='drinking',y='weight',hue='gender')#세로 상자 수염 그래프
sns.boxplot(data=data6,y='drinking',x='weight',hue='gender',orient='h')#가로 상자 수염 그래프
# plt.ylim(30,100)
plt.xlim(30,100)
plt.show()

# %% [markdown]
# 3.6) 카운트 플롯 그래프
# - 범주형 데이터에 대해 항목별 개수를 세어 막대 그래프로 표현한다.
# - 각 범주별로 데이터가 얼마나 있는지 표현할 수 있고 해당 열을 구성하고 있는 값들을 구분하여 보여준다.

# %%
plt.figure(figsize=(10,6))
plt.title('Seaborn Count Plot Graph')

# sns.countplot(data=data6,x='drinking',hue='gender')
sns.countplot(data=data6,y='drinking',hue='gender',order=['Drinking','Non-drinking'])#순서 지정, 가로 카운트 플롯
plt.show()

# %% [markdown]
# 3.7) 바이올린 플롯 그래프
# - 커널 밀도 추정치를 이용하여 그래프를 그리고 분포에 대한 결과를 보일때 효과적
# - 작은 샘플크기는 오해의 소지가 있을 수 있다.

# %%
plt.figure(figsize=(10,6))
plt.title('Seaborn Violin Plot Graph')

# sns.violinplot(data=data6[data.weight<100],x='gender',y='weight',hue='drinking')
sns.violinplot(data=data6[data.weight<100],y='gender',x='weight',hue='drinking')#가로바이올린플롯 그래프
plt.show()

# %% [markdown]
# 3.8) 시본 히트맵 그래프
# - 데이터가 2차원이고 보든 값이 범주형 값이면 히트맵 그래프로 표현하기 좋다.
# - 두 개의 범주형 값에 의한 실수값의 변화를 확인 할 수 있다.
# - corr()함수로 상관관계 정도를 수치로 나타낸 계수를 구하여 히트맵 그래프로 표현한다. 상관계수는 1에 가까울수록 상관관계가 높다. 인과관계는 x

# %%
data3=data.loc[:,['gender','weight','waist']]
data8=data.loc[:,['gender','weight','waist','drinking','smoking','cholesterol','HDL','LDL']]

# %%
plt.figure(figsize=(10,6))
plt.title('Heat Map')

correlation_data3=data3.corr()
upp_mat=np.triu(correlation_data3)#상단 영역이 보이지 않게 지정 tril()은 하단 영역 보이지 않게 한다.
print(correlation_data3)
sns.heatmap(correlation_data3,annot=True,cmap='coolwarm', mask=upp_mat)#annot 속성 활성화시켜 상관계수 수치표시, cmap으로 색상 지정
plt.show()
# Out:
#           gender    weight     waist
# gender  1.000000 -0.582641 -0.431970
# weight -0.582641  1.000000  0.787645
# waist  -0.431970  0.787645  1.000000

# %% [markdown]
# 3.9) 다중 플롯 그리드 그래프
# - 다양한 범주의 값을 가지는 데이터에 대하여 다양한 형태의 그래프를 다차원 그리드로 시각화하기에 ㄷ좋다.
# - facet grid, pair plot, join plot 그래프 등이 있다.

# %%
#facet grid
fg=sns.FacetGrid(data6, col='drinking', row='gender', height=4.5, aspect=1.5)#aspect는 세로 대비 가로 비율을 지정,
fg.map(sns.histplot, 'waist', bins=10, color='g',kde=True)
fg.set_ylabels('waist_counts')
plt.show()

# %%
#pairplot
#3차원 이상의 다차원 실수횽 데이터를 시각화할 때 적당하다.
#데이터에서 각각 2개 열 열 간의 관계를 그래프로 표현한다.
#다양한 기능이나 세부적인 설정을 뭔할때는 pairgrid()함수를 이용한다.
#숫자가 아닌 열은 페어 플롯 그래프에 나타나지 않는다.
print(data6)
sns.pairplot(data6, height=3.3,aspect=1.3)
plt.show()
# Out:
#      gender  height  weight  waist      drinking      smoking
# 0      Male     165      60   72.1  Non-drinking  Non-smoking
# 1    Female     150      65   81.0  Non-drinking  Non-smoking
# 2    Female     155      55   70.0  Non-drinking  Non-smoking
# 3      Male     160      70   90.8  Non-drinking  Non-smoking
# 4    Female     155      50   75.2  Non-drinking  Non-smoking
# ..      ...     ...     ...    ...           ...          ...
# 995    Male     165      70   92.0      Drinking      Smoking
# 996    Male     165      70   88.0  Non-drinking  Non-smoking
# 997  Female     155      55   80.2      Drinking  Non-smoking
# 998  Female     150      55   79.5  Non-drinking  Non-smoking
# 999    Male     160      60   86.0      Drinking  Non-smoking
#
# [1000 rows x 6 columns]

# %%
color=['r','b']
pp=sns.PairGrid(data6, hue='gender', palette=color,height=3.3, aspect=1.3)
pp.map_diag(sns.histplot,bins=10,kde=True)
pp.map_offdiag(sns.scatterplot)
pp.add_legend()
plt.show()

# %% [markdown]
# **연습문제**

# %% [markdown]
# 연습 4)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data=pd.read_excel('health_screenings_2020_1000ea.xlsx')
data3=data.loc[:,['city_code', 'gender', 'waist']]

male_data=data3[data3['gender']==1].groupby('city_code')['waist'].mean()
female_data=data3[data3['gender']==2].groupby('city_code')['waist'].mean()

plt.figure(figsize=(12,4))
plt.plot(male_data,label='Male',color='b',marker='o',linestyle='--')
plt.plot(female_data,label='Female',color='r',marker='o',linestyle='--')
plt.xlabel('Count')
plt.ylabel('Waist')
plt.title('Line Graph')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# 연습 5)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data=pd.read_excel('health_screenings_2020_1000ea.xlsx')
data3=data.loc[100:110,['waist']]

plt.figure(figsize=(10,5))

plt.bar(data3.index,data3['waist'],color='b')

plt.ylim(50, 110)
plt.xlabel('Count')
plt.ylabel('Waist')
plt.title('Bar Graph')
plt.grid()
plt.show()

# %% [markdown]
# 연습 6)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data=pd.read_excel('health_screenings_2020_1000ea.xlsx')
lEyeData=data['eye_left']
rEyeData=data['eye_right']

plt.figure(figsize=(5,5))

plt.scatter(lEyeData,rEyeData,color='b')

plt.xlim(0,2.5)
plt.ylim(0,2.5)
plt.xlabel('Left Eye')
plt.ylabel('Right Eye')
plt.title('Scatter Graph')
plt.grid()
plt.show()

# %% [markdown]
# 연습 7)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data=pd.read_excel('health_screenings_2020_1000ea.xlsx')
data3=data.loc[:,['city_code','gender','waist']]

male_data=data3.loc[data3['gender']==1,['gender','waist']]
female_data=data3.loc[data3['gender']==2,['gender','waist']]

plt.figure(figsize=(10,6))

plt.hist(male_data['waist'], bins=8, label='Male',color='b', alpha=0.5)
plt.hist(female_data['waist'], bins=8, label='Female',color='orange', alpha=0.5)

plt.xlim(50,115)
plt.xlabel('Waist')
plt.ylabel('Frequency')
plt.title('Histogram Graph')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# 연습 8)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data=pd.read_excel('health_screenings_2020_1000ea.xlsx')
data3=data.loc[:,['city_code','gender','waist']]

mandata=data3.loc[data3['gender']==1,['gender','waist']]
womandata=data3.loc[data3['gender']==1,['gender','waist']]

male=np.array(mandata['waist'], dtype=object)
female=np.array(womandata['waist'])

plt.figure(figsize=(10,5))

plt.boxplot([male,female],labels=['Male','Female'],vert=True)
plt.xlabel('Gender')
plt.ylabel('Waist')
plt.title('Boxplot Graph')
plt.show()

# %% [markdown]
# 연습 9)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data=pd.read_excel('health_screenings_2020_1000ea.xlsx')
data6=data.loc[:,['gender','height','weight','waist', 'drinking','smoking']]

data6.loc[data6['gender']==1,['gender']]='Male'
data6.loc[data6['gender']==2,['gender']]='Female'
data6.loc[(data6['smoking']==1)|(data6['smoking']==2),['smoking']]='Non-smoking'
data6.loc[data6['smoking']==3,['smoking']]='Smoking'

smoking=data6.groupby(['gender','smoking'])['smoking'].count()
smoking=smoking.to_frame(name='count').reset_index()
smoking

plt.figure(figsize=(10,6))
sns.barplot(data=smoking, x='smoking',y='count', hue='gender', order=['Smoking','Non-smoking'])
plt.title('Smoking Count Plot Graph')
plt.show()

# %% [markdown]
# 연습 10)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data=pd.read_excel('health_screenings_2020_1000ea.xlsx')
data6=data.loc[:,['gender','height','weight','waist', 'drinking','smoking']]

data6.loc[data6['gender']==1,['gender']]='Male'
data6.loc[data6['gender']==2,['gender']]='Female'
data6.loc[(data6['smoking']==1)|(data6['smoking']==2),['smoking']]='Non-smoking'
data6.loc[data6['smoking']==3,['smoking']]='Smoking'

smoking=data6.groupby(['gender','smoking'])['smoking'].count()
smoking=smoking.to_frame(name='count').reset_index()

plt.figure(figsize=(10,6))
sns.violinplot(data=data6, x='gender', y='weight', hue='smoking', order=['Male','Female'])
plt.title('Violin Plot Graph')
plt.show()

# %% [markdown]
# 연습 11)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data=pd.read_excel('health_screenings_2020_1000ea.xlsx')
data6=data.loc[:,['gender','height','weight','waist', 'drinking','smoking']]

plt.figure(figsize=(10,6))

correlation_data6=data6.corr()
upp_mat=np.triu(correlation_data6)

sns.heatmap(correlation_data6, annot=True, mask=upp_mat)
plt.title('Heat Map')
plt.show()
